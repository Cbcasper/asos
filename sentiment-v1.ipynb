# %%
import pandas

asos_path = "asos-v1.xlsx"
asos_dataframe = pandas.read_excel(asos_path, header=1).rename(columns=lambda column_name: column_name.lower())
asos_dataframe.drop(asos_dataframe.tail(2).index, inplace=True)

review_column = "review_text"
sentiment_column = "tone"
multilabel_columns = asos_dataframe.columns[-27:]

asos_dataframe[multilabel_columns] = asos_dataframe[multilabel_columns].fillna(False).astype(bool)

asos_dataframe[[review_column, sentiment_column, *multilabel_columns]]
# Out:
#                                            review_text      tone    fit  \
# 0    Great Color but impossible to wear, makes too ...   neutral  False
# 1    I don‚Äôt understand why some people say that ...   neutral   True
# 2    The first think I noticed out of the bag was a...  negative   True
# 3    I wanted to love these but sadly returned as t...  negative   True
# 4    I will be sending these back, not true to size...  negative   True
# ..                                                 ...       ...    ...
# 194  This will be perfect for when I go on holiday....  positive   True
# 195  Waste of money having to pay for duties and th...  negative  False
# 196  I‚Äôm so glad I bought this dress. Usually I d...  positive  False
# 197  Are usually wear a 10/12 in dresses I am an E ...   neutral   True
# 198  At ¬£42 I‚Äôd expect the dress to at least be ...  negative  False
#
#      durable materials  fabric  durability in use  price  \
# 0                False   False              False  False
# 1                False   False              False  False
# 2                False   False              False  False
# 3                False   False              False  False
# 4                False   False              False  False
# ..                 ...     ...                ...    ...
# 194              False   False              False  False
# 195              False   False              False   True
# 196              False   False              False  False
# 197              False   False              False  False
# 198              False    True              False  False
#
#      durability while laundering  manufacturing (sewing)  suitability in use  \
# 0                          False                   False               False
# 1                          False                   False               False
# 2                          False                   False               False
# 3                          False                   False               False
# 4                          False                   False               False
# ..                           ...                     ...                 ...
# 194                        False                   False                True
# 195                        False                   False               False
# 196                        False                   False               False
# 197                        False                   False               False
# 198                        False                    True               False
#
#      ...  ethcally  ecological  long life span  reason why returned  \
# 0    ...     False       False           False                 True
# 1    ...     False       False           False                False
# 2    ...     False       False           False                 True
# 3    ...     False       False           False                False
# 4    ...     False       False           False                 True
# ..   ...       ...         ...             ...                  ...
# 194  ...     False       False           False                False
# 195  ...     False       False           False                 True
# 196  ...     False       False           False                False
# 197  ...     False       False           False                False
# 198  ...     False       False           False                 True
#
#      reason why not returned  match w/ photo  fit suggestions  \
# 0                      False           False            False
# 1                      False           False             True
# 2                      False           False            False
# 3                      False           False            False
# 4                      False           False            False
# ..                       ...             ...              ...
# 194                    False           False            False
# 195                    False           False            False
# 196                    False           False            False
# 197                    False           False             True
# 198                    False           False            False
#
#      style suggestions  practicality  feelings
# 0                False         False     False
# 1                False         False     False
# 2                False         False     False
# 3                False         False     False
# 4                False         False     False
# ..                 ...           ...       ...
# 194              False         False     False
# 195              False         False     False
# 196              False         False     False
# 197              False         False     False
# 198              False         False     False
#
# [199 rows x 29 columns]

# %%
sentiments = ["positive", "neutral", "negative"]

# %%
import torch

device = torch.device("cpu")
device_string = "cpu"
if torch.backends.mps.is_available():
    device = torch.device("mps")
    device_string = "mps"
if torch.cuda.is_available():
    device = torch.device("cuda:0")
    device_string = "cuda:0"

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("google/gemma-2b-it", token="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")
model = AutoModelForCausalLM.from_pretrained("google/gemma-2b-it", token="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").to(device)
# Out:
# Gemma's activation function should be approximate GeLU and not exact GeLU.
# Changing the activation function to `gelu_pytorch_tanh`.if you want to use the legacy `gelu`, edit the `model.config` to set `hidden_activation=gelu`   instead of `hidden_act`. See https://github.com/huggingface/transformers/pull/29402 for more details.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
def run_model(*prompts):
    input_ids = tokenizer("\n".join(prompts), return_tensors="pt").to(device)
    outputs = model.generate(
        **input_ids,
        do_sample=True,
        max_new_tokens=200,
        temperature=1.2,
        top_k=50,
        top_p=0.9,
        repetition_penalty=1.5,
    )
    return tokenizer.decode(outputs[0])

# %%
import torch
from tqdm import tqdm

stride = 1

# taken from https://huggingface.co/docs/transformers/perplexity
def get_perplexity(*prompts, progress=False):
    encodings = tokenizer("\n".join(prompts), return_tensors="pt")
    max_length = model.config.max_position_embeddings
    seq_len = encodings.input_ids.size(1)

    nlls = []
    prev_end_loc = 0
    locs = tqdm(range(0, seq_len, stride)) if progress else range(0, seq_len, stride)
    for begin_loc in locs:
        end_loc = min(begin_loc + max_length, seq_len)
        trg_len = end_loc - prev_end_loc  # may be different from stride on last loop
        input_ids = encodings.input_ids[:, begin_loc:end_loc].to(device)
        target_ids = input_ids.clone()
        target_ids[:, :-trg_len] = -100

        with torch.no_grad():
            outputs = model(input_ids, labels=target_ids)

            # loss is calculated using CrossEntropyLoss which averages over valid labels
            # N.B. the model only calculates loss over trg_len - 1 labels, because it internally shifts the labels
            # to the left by 1.
            neg_log_likelihood = outputs.loss

        nlls.append(neg_log_likelihood)

        prev_end_loc = end_loc
        if end_loc == seq_len:
            break

    return torch.exp(torch.stack(nlls).mean())

# %%
print(get_perplexity("Who was the US president in 2010? Barack Obama"))
print(get_perplexity("Who was the US president in 2010? Donald Trump"))
# Out:
# tensor(1015.7299, device='mps:0')
# tensor(1512.7534, device='mps:0')

# %%
def most_probable_answer(*prompts, answers=None):
    answers = answers or []
    probabilities = [(get_perplexity(*prompts, answer).item(), answer) for answer in answers]
    return sorted(probabilities)

# %%
most_probable_answer("Who was the US president in 2010? ", answers=["George Bush", "Donald Trump", "Barack Obama"])
# Out:
# [(716.4212646484375, 'Barack Obama'),
#  (1189.866455078125, 'Donald Trump'),
#  (1567.660888671875, 'George Bush')]

# %%
review_sentiments = asos_dataframe[[review_column, sentiment_column]].to_numpy()

# %%
import random

review, sentiment = random.choice(review_sentiments)
question = "What is the sentiment of the following review of a clothing item?"

print(f"{review}\n{sentiment}")
print(most_probable_answer(question, "REVIEW:", review, "The sentiment is ", answers=sentiments))
print(run_model(question, "REVIEW:", review, "The sentiment is "))
# Out:
# Happy with this! I‚Äôm anywhere between 10 - 14 depending on brand and the 12 was right for me.
# positive
# [(296.5985412597656, 'positive'), (326.2908935546875, 'neutral'), (366.61968994140625, 'negative')]
# <bos>What is the sentiment of the following review of a clothing item?
# REVIEW:
# Happy with this! I‚Äôm anywhere between 10 - 14 depending on brand and the 12 was right for me.
# The sentiment is 5 out of 5, suggesting that the customer is happy with their purchase.<eos>

# %%
for review, sentiment in review_sentiments:
    question = "What is the sentiment of the following review of a clothing item?"

    print(f"{review}\n{sentiment}")
    answer = most_probable_answer(question, "REVIEW:", review, "The sentiment is ", answers=sentiments)
    print(answer)
    # print(1 - (answer[0][0] / answer[1][0]))
    print()
    # print(run_model(question, "REVIEW:", review, "The sentiment is "))
# Out:
# Great Color but impossible to wear, makes too much noise when walking! would have kept it otherwise. will return
# neutral
# [(668.9400024414062, 'negative'), (792.3026733398438, 'neutral'), (843.6640014648438, 'positive')]
#
# I don‚Äôt understand why some people say that it‚Äôs too big‚Ä¶ It‚Äôs too small for my size (36) and I weight 55kg. I will size up for sure.
# neutral
# [(115.72589874267578, 'negative'), (121.41893005371094, 'neutral'), (121.44758605957031, 'positive')]
#
# The first think I noticed out of the bag was a fishy/chemical smell. It was not flattering at all if you have even a little bit of curve. It made a loud awful plastic noise when walking or moving. Returned.
# negative
# [(178.47996520996094, 'negative'), (196.32516479492188, 'neutral'), (202.2724609375, 'positive')]
#
# I wanted to love these but sadly returned as they were too big. The colour and style is great but these trousers are not petite in my opinion
# negative
# [(172.5623779296875, 'negative'), (188.97222900390625, 'neutral'), (204.2418670654297, 'positive')]
#
# I will be sending these back, not true to size\r\nLook cheap, poor quality
# negative
# [(330.1042175292969, 'negative'), (391.9695739746094, 'neutral'), (426.56292724609375, 'positive')]
#
# The colour, texture and cut is flattering, fits me so well
# positive
# [(611.9151000976562, 'positive'), (789.8925170898438, 'neutral'), (840.7215576171875, 'negative')]
#
# Omg it feels so soft to handle. Grey is my new favourite colour. I can't wait to wear it
# positive
# [(209.38943481445312, 'positive'), (256.03759765625, 'neutral'), (263.7763977050781, 'negative')]
#
# Well constructed outfit. I love the design and fabric. It's sporty and chic and received alot of compliments.  Finally an outfit that is stylish and respects curvy women!
# positive
# [(188.5650177001953, 'positive'), (217.78851318359375, 'neutral'), (232.3140411376953, 'negative')]
#
# Love this jumper dress. Great quality fabric and fits well. Want to get another one for back up üòÜ
# positive
# [(378.428466796875, 'positive'), (444.59600830078125, 'neutral'), (479.654296875, 'negative')]
#
# I bought this a few weeks ago to wear to a family event and absolutely love it. Its so cute and stylish. It looks just like the picture. It's so comfortable. It does stretch when wearing it, making it bigger but I love the oversized look. Had lots of compliments.
# positive
# [(65.81590270996094, 'positive'), (72.27325439453125, 'neutral'), (75.81236267089844, 'negative')]
#
# Love this dress the material is gave and it‚Äôs true to size well worth the money
# positive
# [(392.5999755859375, 'positive'), (468.3387145996094, 'neutral'), (518.604248046875, 'negative')]
#
# I bought this dress thinking it might come and not be as sen onsite \r\nIt was great , fitted perfectly and great colour
# positive
# [(516.9098510742188, 'positive'), (635.1939697265625, 'neutral'), (651.9718627929688, 'negative')]
#
# Happy with this! I‚Äôm anywhere between 10 - 14 depending on brand and the 12 was right for me.
# positive
# [(296.5985412597656, 'positive'), (326.2908935546875, 'neutral'), (366.61968994140625, 'negative')]
#
# The colour isn't brown as in the pic but much more purple & the fit is quite odd - very large
# negative
# [(340.06744384765625, 'negative'), (389.58319091796875, 'neutral'), (401.614990234375, 'positive')]
#
# If you have a butt it will not fit. And the upper part is too big.
# negative
# [(234.49227905273438, 'negative'), (261.42474365234375, 'neutral'), (278.05712890625, 'positive')]
#
# was just quite baggy and sleeves were very long. You not only have to be tall but quite broad for this to work.
# negative
# [(237.61917114257812, 'negative'), (271.2505798339844, 'neutral'), (275.04461669921875, 'positive')]
#
# This dress was a terrible fit and the fabric looked purple not brown! Returned
# negative
# [(544.969970703125, 'negative'), (642.3373413085938, 'neutral'), (695.0225830078125, 'positive')]
#
# Really plasticy and so small - super short for a tall. Have bought leather trousers from this brand before which I love but they‚Äôre totally different! Returned.
# negative
# [(528.5050659179688, 'negative'), (589.6327514648438, 'neutral'), (615.47998046875, 'positive')]
#
# The pants Smells like fish and it is too big Even tho i got my usual size
# negative
# [(372.20135498046875, 'negative'), (452.3890075683594, 'neutral'), (471.12042236328125, 'positive')]
#
# Smells like dead fish, size runs small, would order a size up
# negative
# [(210.63600158691406, 'negative'), (257.59161376953125, 'neutral'), (266.8201904296875, 'positive')]
#
# This is a lovely jumper with matching scarf which really gives it a very smart and classy look and feel. \r\n\r\nSlightly oversized fit so very comfortable to wear and very warm.
# positive
# [(171.3762969970703, 'positive'), (194.1140594482422, 'neutral'), (204.84228515625, 'negative')]
#
# Yeah it‚Äôs a bit square but the stitching is lovely and the arm length amazing. Black faux leather biker style leggings and a black vest, chunky boots  and you‚Äôre good to go!
# positive
# [(391.8713073730469, 'positive'), (432.82684326171875, 'neutral'), (461.0046081542969, 'negative')]
#
# I cannot put into words how much this sheds. I wore it once and as soon as I put my black wool coat on, it left long cream/ white fibres all over my coat, vests and trousers. I was  embarrassed walking around at work and spent 20 mins lint rolling my coat when I got back. Sending back as poor quality!
# negative
# [(149.20567321777344, 'negative'), (162.60894775390625, 'neutral'), (163.83123779296875, 'positive')]
#
# Great quality and fit but I had to size down to a size 2‚Ä¶ usually between 4-6.. most of the time 6.
# positive
# [(272.04693603515625, 'positive'), (282.4410400390625, 'neutral'), (282.6935119628906, 'negative')]
#
# The threads in the plisse detailing came undone and left holes in garment. Not great quality.
# negative
# [(325.6916809082031, 'negative'), (368.84942626953125, 'neutral'), (411.3431396484375, 'positive')]
#
# Love the top if you are going for a looser fit fry your normal size if you are going for a tailor fight size down.
# positive
# [(457.977294921875, 'positive'), (489.8652648925781, 'neutral'), (537.4845581054688, 'negative')]
#
# I‚Äôm 5ft10 and this had great length, pretty colour and really comfy
# positive
# [(835.567626953125, 'positive'), (1024.94091796875, 'neutral'), (1140.89404296875, 'negative')]
#
# I liked the dress, the fit was ok but it was cream not white. Wasted of delivery cost.
# neutral
# [(315.0461120605469, 'negative'), (335.8786926269531, 'neutral'), (378.8840026855469, 'positive')]
#
# Beautiful dress but unfortunately was too big for me. Smallest size was 8.
# neutral
# [(290.7546081542969, 'negative'), (322.3721923828125, 'neutral'), (339.6253662109375, 'positive')]
#
# The design is pretty but it shows everything. It's bad material for the price point.
# negative
# [(256.4173278808594, 'negative'), (276.4682922363281, 'neutral'), (313.0812683105469, 'positive')]
#
# Great color to wear for a May wedding.  Can't wait.  Sexy and fits my curves well.  True to size
# positive
# [(255.8013458251953, 'positive'), (311.2729797363281, 'neutral'), (332.7321472167969, 'negative')]
#
# It‚Äôs not flattering at all and it fits awkward on you if you have a bigger chest. The material is nice but that‚Äôs about it.
# negative
# [(152.3970489501953, 'negative'), (159.04415893554688, 'neutral'), (172.78616333007812, 'positive')]
#
# Just bought it , fits great! Very nice material, good quality
# positive
# [(279.27099609375, 'positive'), (346.77667236328125, 'neutral'), (384.3955383300781, 'negative')]
#
# Good quality and length, colour looks great too. Recommend!
# positive
# [(265.7306823730469, 'positive'), (323.83258056640625, 'neutral'), (379.0365295410156, 'negative')]
#
# Material is nice and thick, not see-through. Sleepers fit exactly like on the model, slightly on the long side but I like that.
# positive
# [(120.27755737304688, 'positive'), (131.2798309326172, 'neutral'), (145.23187255859375, 'negative')]
#
# Loved it but had to return because it didn't fit my arm length.
# positive
# [(204.91995239257812, 'negative'), (219.83265686035156, 'neutral'), (238.03207397460938, 'positive')]
#
# This had so much potential. Too much material. The shirt is too long and oversized to properly tuck into the MATCHING pants. Overall bulky. Will definitely need tailoring. Just unflattering
# negative
# [(240.53860473632812, 'negative'), (261.9033508300781, 'neutral'), (280.97430419921875, 'positive')]
#
# I bot this as a set and when it arrived I loved the pants but unfortunately the shirt fit really odd. The fabric on the shirt seemed thicker and not close to the same fabric as the pants. It also had really big cuffs that overwhelmed my arms.
# neutral
# [(120.53241729736328, 'negative'), (124.97855377197266, 'neutral'), (132.55374145507812, 'positive')]
#
# Love this set. Material is lovely - thick \r\nAdvise for any buyer: \r\nTrousers - very long trousers, can wear up to 4inches heels without heel showing‚Ä¶if below 5ft10.5. I ordered size 8, the hip area fits perfectly  but waist is a little loose and would need taking in for perfect fit. If you have fuller hips, size up but waist might be a little loose. \r\nTop (uk size 8) - very long sleeves and I love it! If you want less of the baggy look, size down‚Ä¶.
# positive
# [(106.31107330322266, 'positive'), (110.21243286132812, 'neutral'), (111.0992431640625, 'negative')]
#
# I‚Äôm a 12/14. After reading the reviews of this shirt I ordered a 10 so that it would just be baggy, however it is still humongous! I love it though! Very good quality.
# positive
# [(129.55137634277344, 'positive'), (140.26446533203125, 'neutral'), (146.36334228515625, 'negative')]
#
# Nice to wear once. After a clean it‚Äôs awful. Wish someone had left a review on this before I purchased
# negative
# [(590.7072143554688, 'negative'), (659.74365234375, 'neutral'), (712.7035522460938, 'positive')]
#
# Not much to say about this other than it‚Äôs absolutely gigantic and hence has zero shape. Quality is fine though.
# negative
# [(393.40313720703125, 'neutral'), (395.84295654296875, 'negative'), (442.2555847167969, 'positive')]
#
# The shirt was extremely too big and the arms were not long enough
# negative
# [(393.3003845214844, 'negative'), (488.7048034667969, 'neutral'), (494.1758117675781, 'positive')]
#
# Excited for the dress, when I recieved it the quality was not what I expected. Disappointing
# negative
# [(178.96717834472656, 'negative'), (215.95501708984375, 'neutral'), (228.63612365722656, 'positive')]
#
# Bought this for my daughters after wedding dinner. She loves it
# positive
# [(575.1900634765625, 'positive'), (734.1780395507812, 'neutral'), (814.126708984375, 'negative')]
#
# Dress looks so lovely on however it is very short for a tall item. It is more of a long blazer
# positive
# [(309.0110168457031, 'negative'), (344.2158508300781, 'neutral'), (347.0688171386719, 'positive')]
#
# Weird closure, weird fit, bad quality, runs large, returned
# negative
# [(535.57421875, 'negative'), (647.1480712890625, 'neutral'), (690.4898071289062, 'positive')]
#
# Great quality , sadly had to send it back it was waaay to long. And I‚Äôm 1.80cm
# positive
# [(494.4652404785156, 'negative'), (561.3436279296875, 'neutral'), (583.0905151367188, 'positive')]
#
# I think these trousers would be lovely if they fit but they were just so long and very loose around the waist and hips. I‚Äôm 5‚Äô11 and usually buy Tall trousers but these pooled around my feet and even when I tried them on with heels they dragged on the ground. They also run a little large, I‚Äôm usually a 12 in trousers but these were very baggy on the waist and crotch.
# negative
# [(63.938720703125, 'negative'), (66.51177978515625, 'neutral'), (67.65990447998047, 'positive')]
#
# Gorgeous colour and quality, length is great (5‚Äô11 for reference) however the waist is far too high and too long crotch!
# positive
# [(567.326904296875, 'negative'), (631.1638793945312, 'neutral'), (634.622314453125, 'positive')]
#
# These pants are a gorgeous colour blue and a perfect fit.  I am 6 feet tall and its almost impossible to find pants long enough-I will buy from ASOS again for sure.
# positive
# [(134.03741455078125, 'positive'), (152.32765197753906, 'neutral'), (161.2955780029297, 'negative')]
#
# Love this, washes really well but probably isn‚Äôt the best for girlies with bigger boobs, mine do pop out if I move to much so probs more of a sunbathing / spa costume
# positive
# [(511.2746887207031, 'negative'), (549.3168334960938, 'neutral'), (579.30810546875, 'positive')]
#
# The swimsuit looks exactly like the photograph however the top two sections rolled down and practically not a good cover up.
# neutral
# [(648.8593139648438, 'negative'), (683.3678588867188, 'neutral'), (738.289306640625, 'positive')]
#
# Not as depicted in the photo. Loved it on the model but it is SO CHEEKY and does t seem like top will stay up
# negative
# [(546.4091796875, 'negative'), (613.0263671875, 'neutral'), (651.470947265625, 'positive')]
#
# Nice material. It‚Äôs not hot and not quite linen. It looks black and white on the picture but it‚Äôs more of a black and tan/cream. Long shirt though. I don‚Äôt understand.
# positive
# [(174.08364868164062, 'neutral'), (176.51629638671875, 'negative'), (177.78175354003906, 'positive')]
#
# The material is not breathing at all. Overall it is good and fitting nicely. Small size is good since it‚Äôs little oversized. Quality is fine but not amazing.
# neutral
# [(312.3600158691406, 'neutral'), (318.1426086425781, 'negative'), (329.33978271484375, 'positive')]
#
# On the pictures this set looks black and white when in reality there is no white it looks something like dark blue/grey mix.
# negative
# [(396.3614501953125, 'negative'), (424.9935302734375, 'neutral'), (449.9262390136719, 'positive')]
#
# I was concerned about the material ripping since it is so thin. I returned them. Not the quality I expected.
# negative
# [(196.071533203125, 'negative'), (225.45709228515625, 'neutral'), (240.6947479248047, 'positive')]
#
# They are good, but the material is not breathing at all. I took size Medium , normally I have Small, but I think it looks better when shorts are little bit loose and you can wear it with a belt.
# negative
# [(190.7751922607422, 'positive'), (192.82713317871094, 'neutral'), (192.9275665283203, 'negative')]
#
# On the pictures this set looks black and white when in reality there is no white it looks something like dark blue/grey mix. \r\nAnd on top of that runs small
# negative
# [(298.74395751953125, 'negative'), (320.395751953125, 'neutral'), (337.3529968261719, 'positive')]
#
# Really lovely shorts, look great on. A little on the thin side but that's not a bad thing in the summer.
# positive
# [(110.32174682617188, 'positive'), (122.37601470947266, 'neutral'), (135.42483520507812, 'negative')]
#
# Returned.\r\nSize runs a bit larger than expected. \r\nI would get a size down otherwise it does sit well at the back and boob areas
# neutral
# [(179.318603515625, 'negative'), (186.6457061767578, 'neutral'), (196.25169372558594, 'positive')]
#
# I bought this an an option for a holiday, the quality was lovely but unfortunately it was a bit big and fit a bit funny on my bust as I don‚Äôt have a big cup size. I think for someone with cup size C & above it would fit lovely.
# positive
# [(98.88946533203125, 'negative'), (100.75241088867188, 'positive'), (101.25831604003906, 'neutral')]
#
# The fit it's okay. you will need to size down it's very stretchy. I only kept it because it was final sale no return on this. I'm usually a 6 but I got a 4 and it still feels a bit loose. I think is that type of material that will stretch out the more you wear it.
# neutral
# [(60.99140930175781, 'neutral'), (61.1051139831543, 'negative'), (63.0465087890625, 'positive')]
#
# This dress is really beautiful! I got in size 6 first but had to exchange for 4 as it was slipping down (Im 5.6‚Äô and 135lb for reference). It sits really great and quality is good. The material is little heavy so Im not sure if its gonna stretch after some time but so far Im very happy with the dress
# positive
# [(105.53044128417969, 'positive'), (112.68120574951172, 'neutral'), (117.21691131591797, 'negative')]
#
# I bough this for my vacation to Miami and I‚Äôm so glad I did.
# positive
# [(395.8314514160156, 'positive'), (498.5715637207031, 'neutral'), (524.4092407226562, 'negative')]
#
# The fabric is so soft and the dress is super flattering. Ideal if you have bigger boobs as well as the top bit has good coverage (I‚Äôm size 6 and DD cup)
# positive
# [(318.6325378417969, 'positive'), (366.18115234375, 'neutral'), (386.80474853515625, 'negative')]
#
# It is beautiful but too short... I recommend to take one size more.
# neutral
# [(220.2874298095703, 'negative'), (234.50192260742188, 'neutral'), (240.94497680664062, 'positive')]
#
# It doesn‚Äôt accommodate the standard body shape. Just doesn‚Äôt work and I had to return it. The fabric feels good though
# negative
# [(216.1070556640625, 'negative'), (224.77964782714844, 'neutral'), (250.37437438964844, 'positive')]
#
# I bought this and unfortunately had to immediately return it. It is quite heavy and a good material however I found the fitting to be rather odd, it was much smaller in the skirt section and vastly larger in the top especially the chest. I am 5‚Äô3 and ordered a size 12 as I am quite busty so I was shocked at the proportions.
# negative
# [(104.77027893066406, 'negative'), (110.96149444580078, 'neutral'), (113.33663177490234, 'positive')]
#
# The fitting in this blazer is absolutely awful. Super tight through the hips and absolutely gaping through the top. Absolutely do not recommend.
# negative
# [(203.45724487304688, 'negative'), (232.7325897216797, 'neutral'), (249.89620971679688, 'positive')]
#
# Unfortunately the blazer didn‚Äôt fit as too large on the top half but just fitting wound the hips. Disappointed as otherwise very nice. Darker shade than shown in picture.
# negative
# [(471.32666015625, 'negative'), (489.44451904296875, 'neutral'), (521.9691162109375, 'positive')]
#
# So freaking cute and comfortable! I've been wearing this to the beach with a bikini underneath (just seethrough enough but not too much) and with nude underwear if I'm just going out wearing it. The sleeves are my favourite‚ù§Ô∏è
# positive
# [(352.2967529296875, 'positive'), (380.1306457519531, 'neutral'), (393.0774230957031, 'negative')]
#
# This dress has so much potential but didn‚Äôt work for me. The sleeves are too baggy and the color is too yellow, I loved the dress itself so much I contemplated cutting the sleeves off and making it a halter but for the price point that didn‚Äôt seem justified. Supppeerrr cute just didn‚Äôt work for me
# negative
# [(147.96728515625, 'negative'), (154.5654296875, 'neutral'), (161.35581970214844, 'positive')]
#
# It‚Äôs sheer so really just as beachwear but it the prettiest one in my closet !!!
# positive
# [(1197.8779296875, 'positive'), (1466.8094482421875, 'neutral'), (1529.771728515625, 'negative')]
#
# So flattering, comfortable and an actual swimsuit that you don‚Äôt need to size up to make you feel comfortable and bum look good. \r\nFor reference I‚Äôm an 8/10 5ft5 and got a 10,
# positive
# [(181.7711181640625, 'positive'), (201.2520751953125, 'neutral'), (205.4124298095703, 'negative')]
#
# Brilliant swim suit. Wore to a spa day and felt great. Got a size 14 as between 12-14 with large chest but probably could have sized down to a 12. Love it.
# positive
# [(150.78109741210938, 'positive'), (168.19940185546875, 'neutral'), (177.5085906982422, 'negative')]
#
# Love it, would liked it if it came with some padding though
# positive
# [(635.2960205078125, 'negative'), (650.8245239257812, 'positive'), (655.0116577148438, 'neutral')]
#
# The fit on this is amazing. The cuts fall in all the right places. Can‚Äôt wait to wear it on a hen do
# positive
# [(330.008544921875, 'positive'), (397.4871826171875, 'neutral'), (415.1386413574219, 'negative')]
#
# By far the most amazing swimsuit I have ever had. Super flattering, so stylish and feels timeless. So happy I purchased!
# positive
# [(132.68141174316406, 'positive'), (162.18511962890625, 'neutral'), (169.14927673339844, 'negative')]
#
# I bought last month.. I regret it . Too big and boxy even though I bought a size down
# negative
# [(323.9085998535156, 'negative'), (395.47186279296875, 'neutral'), (403.1878356933594, 'positive')]
#
# Amazing coat, great quality as always from 4th and reckless, but runs large
# positive
# [(751.4154663085938, 'negative'), (847.2964477539062, 'neutral'), (871.3729248046875, 'positive')]
#
# Nice quality for the cheap price, would perhaps last 2 seasons. Unfortunately it was massively oversized. I am usually a 14 if something has buttons or needs to close across the chest, the recommended size did say 12 which I ignored and fot the 14. It was really big so definitely take your recommended size. I sent back and did not reorder as the sleeves were also super long, this plus the length of the coat on my short frame made me feel like a kid wearing my dads coat.
# neutral
# [(137.70703125, 'negative'), (141.8921356201172, 'neutral'), (143.9658203125, 'positive')]
#
# Perfect for cold winter days. The cut of it wasn't right for me so I returned it but I was gutted to have to do so. Really lovely coat.
# positive
# [(141.95127868652344, 'negative'), (146.28399658203125, 'neutral'), (150.8562469482422, 'positive')]
#
# Gorgeous coat but the shape didn't flatter my tummy area.  Thick and seemed great quality
# positive
# [(914.8302001953125, 'negative'), (972.1920166015625, 'neutral'), (1014.70361328125, 'positive')]
#
# I was looking for a dress for my registry office wedding . I'm not a lace and flowery kind of person so this is perfect. It fits like a glove in all the right places and feels amazing. I will dress it up with a jacket but can definitely wear it on my honeymoon too. It will be a great dress for parties too
# positive
# [(85.89662170410156, 'positive'), (93.99539947509766, 'neutral'), (98.05970764160156, 'negative')]
#
# I wore this for my courthouse wedding and worked well enough. The ruching was forgiving to my midriff but the material wasn‚Äôt the thickest so some of my cellulite was on full blast. Overall, it‚Äôs good for the price and looks chic styled with high boots.
# positive
# [(184.4658660888672, 'positive'), (186.7928009033203, 'neutral'), (192.65728759765625, 'negative')]
#
# The dress fit and felt really nice but the colour didn‚Äôt suit so I returned it. Would buy again in other colours.
# positive
# [(184.4800262451172, 'neutral'), (185.38035583496094, 'positive'), (187.85171508789062, 'negative')]
#
# Super comfy and flattering. I wore for black tie event but can dress down too
# positive
# [(406.6753234863281, 'positive'), (488.0078125, 'neutral'), (541.2407836914062, 'negative')]
#
# Quality wasn‚Äôt the same as picture. Would prefer better quality and not stretchy material
# negative
# [(745.206787109375, 'negative'), (855.535888671875, 'neutral'), (934.8565063476562, 'positive')]
#
# Perfect! Lovely quality and perfect fit. Would recommend
# positive
# [(384.9234313964844, 'positive'), (517.3426513671875, 'neutral'), (568.7236938476562, 'negative')]
#
# Very beautiful beige top. Exactly like in the photos. Goes with original beige pants or can be worn with white or black pants. Perfect summer top.
# positive
# [(196.16851806640625, 'positive'), (222.7890167236328, 'neutral'), (243.82003784179688, 'negative')]
#
# I had my eyes on this 2 piece beige set for a long time. The best purchase so far! The top looks and feels great on my body! The colour is warm and trendy.  Matches with black pants, shorts, skirts, and with white bottom variations.
# positive
# [(127.65768432617188, 'positive'), (140.91452026367188, 'neutral'), (148.1318359375, 'negative')]
#
# I love this and can't wait to wear in the summer and on holiday.  It's a great cover up for bikini days.  Very casual but great quality linen.   I would have loved to get my hands on the matching trousers but they seem to have sold out everywhere.
# positive
# [(63.247291564941406, 'positive'), (68.01968383789062, 'neutral'), (71.66907501220703, 'negative')]
#
# This top has a larger fit, gapes in the front difficult to style.
# neutral
# [(609.13720703125, 'negative'), (683.6008911132812, 'neutral'), (745.5465698242188, 'positive')]
#
# True to size. So pretty perf for any height and great quality
# positive
# [(918.3025512695312, 'positive'), (1165.7301025390625, 'neutral'), (1300.7659912109375, 'negative')]
#
# Love the color, true to fit,fabric is nice as well.
# positive
# [(308.6352233886719, 'positive'), (362.0776062011719, 'neutral'), (418.51934814453125, 'negative')]
#
# Gorgeous fitting - get some many compliments in this. Looks more expensive and really chic.
# positive
# [(494.9903564453125, 'positive'), (621.4867553710938, 'neutral'), (655.713134765625, 'negative')]
#
# So happy I ordered this wanted the black but was out of stock but this is stunning can‚Äôt wait to wear / black came back in stock so ended up buying that as well will be great for upcoming holidays
# positive
# [(207.72764587402344, 'positive'), (236.98922729492188, 'neutral'), (247.24700927734375, 'negative')]
#
# So glad I decided to order this item, it is beautiful! I also purchased the matching top! Really lovely cream colour, true to size, lovely midi length on me and sits high waisted! I am 5‚Äô2‚Äù so someone a lot taller could just have it sitting a little lower on the waist! I am curvy on the hips and rear but it hugs in all the right places but is thick enough with a beautiful crochet pattern that does not show any lumps & bumps!
# positive
# [(127.54092407226562, 'positive'), (136.87921142578125, 'neutral'), (139.48529052734375, 'negative')]
#
# I ordered a US 4 which is my true size and it fit great. Thick material & great quality!
# positive
# [(251.05174255371094, 'positive'), (296.6456298828125, 'neutral'), (327.7242126464844, 'negative')]
#
# I absolutely love this set! I bought both pieces. It‚Äôs great for the beach, club, brunch or any event. I received lot‚Äôs of compliments. The fabric is thick but breathable.
# positive
# [(181.8744659423828, 'positive'), (200.5601348876953, 'neutral'), (215.57875061035156, 'negative')]
#
# Bought it together with hoodie and I absolutely love it. So comfy so chic
# positive
# [(357.1136779785156, 'positive'), (458.8879699707031, 'neutral'), (481.9811706542969, 'negative')]
#
# The worst pant I‚Äôve ever bought.  These are so ugly and shapeless and the colour is horrible, there also short in length  and huge on the waist, the price for these is shocking, bin them asos.
# negative
# [(382.2821350097656, 'negative'), (426.38623046875, 'neutral'), (436.7677001953125, 'positive')]
#
# Bought these beginning of January, unfortunately, when I put them on the other day, one leg was longer than the other and I mean you could notice, so this is why I have left four stars instead of five
# neutral
# [(128.697265625, 'negative'), (139.99977111816406, 'neutral'), (146.07614135742188, 'positive')]
#
# Tried both S and XS and the fit was weird. They might look good eventually in pictures, but for real life and walking around the streets the fit is strange, you would sweep the streets.
# negative
# [(435.6908264160156, 'negative'), (447.4346008300781, 'neutral'), (467.6016845703125, 'positive')]
#
# Love this dress, definitely nice thick material. In between sizes of a true medium and large and ended up going with a size 4. Very stretchy n roomy.
# positive
# [(296.22821044921875, 'positive'), (328.5013122558594, 'neutral'), (361.81390380859375, 'negative')]
#
# Perfect knitted dress. Fabric is so soft.\r\nTrue to size.
# positive
# [(230.50340270996094, 'positive'), (271.80072021484375, 'neutral'), (307.3374328613281, 'negative')]
#
# Really nice dress. Quite a thick knit so not suitable for the summer. It has flared sleeves at the bottom which I did t like. True to size.
# neutral
# [(239.2744140625, 'negative'), (242.61737060546875, 'neutral'), (247.85092163085938, 'positive')]
#
# Love colour and material. Perfect fit and very versatile, well worth the money.
# positive
# [(221.56422424316406, 'positive'), (270.8194580078125, 'neutral'), (301.5231018066406, 'negative')]
#
# Fab. So soft, a lovely shape and great quality. Thanks
# positive
# [(468.9953308105469, 'positive'), (605.2173461914062, 'neutral'), (663.4924926757812, 'negative')]
#
# beautifull, very gorgeous dress, makes you feel wauw!
# positive
# [(451.8330383300781, 'positive'), (608.4544677734375, 'neutral'), (612.92724609375, 'negative')]
#
# Slight weird smell so I would recommend washing before and I also think it is on the slightly bigger side.
# neutral
# [(413.6966857910156, 'neutral'), (421.67816162109375, 'negative'), (443.9983825683594, 'positive')]
#
# Looks fabulous!  True to size‚Ä¶ on trend and a great colour
# positive
# [(836.9967651367188, 'positive'), (1087.9521484375, 'neutral'), (1132.599609375, 'negative')]
#
# This fits perfect, true to size, ordered size 6 which is my normal size. Can‚Äôt wait to wear it! üëèüèª
# positive
# [(246.77622985839844, 'positive'), (282.97406005859375, 'neutral'), (303.48712158203125, 'negative')]
#
# Looks great but it‚Äôs very long and is more of an oversized fit
# positive
# [(430.8173828125, 'negative'), (487.2660827636719, 'neutral'), (527.4514770507812, 'positive')]
#
# Really cute dress. Doesnt look to plastic or cheap, good material, Sizing is accurate
# positive
# [(399.87359619140625, 'positive'), (479.33331298828125, 'neutral'), (535.8414306640625, 'negative')]
#
# Love the shorts. It‚Äôs very Flattering and good quality
# positive
# [(795.789794921875, 'positive'), (984.3087768554688, 'neutral'), (1100.7279052734375, 'negative')]
#
# So cute, perfect length, and nice quality! I would describe them as mid-rise. I think these look great over tights for fall or winter. Since they‚Äôre pleather they don‚Äôt breathe so I wouldn‚Äôt recommend wearing them in the heat!
# positive
# [(121.69575500488281, 'positive'), (127.75250244140625, 'neutral'), (133.50318908691406, 'negative')]
#
# I‚Äôm between sizes 12-14, due to the style/ fit I went for a 12.. they are stunning
# positive
# [(381.0596618652344, 'positive'), (465.6432189941406, 'negative'), (474.5033264160156, 'neutral')]
#
# I have only worn these pants a total of 3 times and the threads are already coming undone, I noticed this from the very first time and it got progressively worse overtime.
# negative
# [(93.11181640625, 'negative'), (102.49153900146484, 'neutral'), (107.37723541259766, 'positive')]
#
# Really good fit and length (5‚Äô5), amazing price and perfect shade of brown
# positive
# [(877.5252685546875, 'positive'), (1073.166259765625, 'neutral'), (1180.7542724609375, 'negative')]
#
# I love it, it's true to size and fits very good. Very beautiful color.
# positive
# [(190.3199005126953, 'positive'), (223.80361938476562, 'neutral'), (253.85667419433594, 'negative')]
#
# Definitely going to be a staple in my closet. It‚Äôs a very relaxed fit so buy your size or size down for a snug fit.
# positive
# [(217.728271484375, 'positive'), (243.75970458984375, 'neutral'), (266.81793212890625, 'negative')]
#
# These trousers hug you in all the right places! A must have!
# positive
# [(232.8477020263672, 'positive'), (293.2972717285156, 'neutral'), (320.8362121582031, 'negative')]
#
# These pants are exactly what I was looking for! They are fitted, but not super tight. They give way when you wear them so you can move comfortably in them. They can be dressed up with heels or worn more casually with sneakers. They are flattering and easy to wear. Whenever I wear them I get a lot of compliments.
# positive
# [(39.34272384643555, 'positive'), (42.498043060302734, 'neutral'), (44.523658752441406, 'negative')]
#
# Had to send it back. It already had tears on it when it got delivered to me. Was really tight, runs small.
# negative
# [(322.7382507324219, 'negative'), (364.6466064453125, 'neutral'), (386.949951171875, 'positive')]
#
# Really good looking pants for going out and/or daily use
# positive
# [(873.7412109375, 'positive'), (1107.234375, 'neutral'), (1255.5538330078125, 'negative')]
#
# Oh how I wished these would have looked like the photo!!! But one leg was a weird tapered inward shape and one leg was a truly slim then flared leg shape. Looked ridiculous. Plus, they fit perfect in the waist but the hips had strange flared out parts? Who is shaped like this? Well, honestly I am a very petite tiny person with no shape but still‚Ä¶ Nobody needs different shaped legs do they? Weird. \r\nRealllly wanted these to work. Love the look on the site.
# negative
# [(234.0380859375, 'negative'), (242.02044677734375, 'neutral'), (246.126708984375, 'positive')]
#
# The fit was very off - short length, extra space on hips (and I already have hips) - all just disporportionate. The smell was awful too.
# negative
# [(437.71990966796875, 'negative'), (487.48779296875, 'neutral'), (511.32659912109375, 'positive')]
#
# I wanted to love this jacket but even getting the size 10 (my normal size), it was MASSIVE! It was super long sleeves‚Ä¶ And it was like a kid wearing a fireman‚Äôs coat! I think even getting an 8, it will be too big!
# negative
# [(255.2279815673828, 'negative'), (271.4781799316406, 'neutral'), (274.3895263671875, 'positive')]
#
# Lovely coat but it was huge, I would have needed two sizes smaller.
# positive
# [(282.4432067871094, 'negative'), (324.0332336425781, 'neutral'), (335.1493225097656, 'positive')]
#
# Lovely looking coat but it does swamp the body, I don‚Äôt wear a lot of black but wanted a smart coat I did send it back due to being too big and didn‚Äôt look nice on me but its still a nice coat depending on the fit you like I‚Äôd size down as it came up large in my opinion
# negative
# [(148.54420471191406, 'negative'), (152.57496643066406, 'neutral'), (156.51541137695312, 'positive')]
#
# Not a nice fit, shoulders too big and bottom part of coat goes in too much. Such an odd shape
# negative
# [(437.43402099609375, 'negative'), (490.0458679199219, 'neutral'), (512.7708129882812, 'positive')]
#
# Gera kokybƒó! Rekomenduoju, modelis labai gra≈æus taip par
# positive
# [(18793.1640625, 'positive'), (23983.197265625, 'neutral'), (24437.595703125, 'negative')]
#
# I was always looking for a good coat, and I am so happy with this coat! It‚Äôs really good.
# positive
# [(263.46356201171875, 'positive'), (309.08233642578125, 'neutral'), (341.4070739746094, 'negative')]
#
# I‚Äôm 5‚Äô8‚Äù and the length was great!! Very happy with the quality too!
# positive
# [(398.28936767578125, 'positive'), (474.6305236816406, 'neutral'), (513.5360107421875, 'negative')]
#
# Lovely coat, looked expensive but looked too long on me am only 5ft 3
# positive
# [(574.46728515625, 'negative'), (662.8499755859375, 'neutral'), (667.0365600585938, 'positive')]
#
# These do look and feel quite cheap, I wouldn‚Äôt recommend.
# negative
# [(639.0494995117188, 'negative'), (718.2042846679688, 'neutral'), (849.1614379882812, 'positive')]
#
# Too short even for 5‚Äô7 height. Such a shame‚Ä¶‚Ä¶‚Ä¶‚Ä¶‚Ä¶..
# negative
# [(200.71176147460938, 'negative'), (235.03163146972656, 'neutral'), (237.50701904296875, 'positive')]
#
# True to size and cute outfit that can be dressed up or down.
# positive
# [(252.8509521484375, 'positive'), (296.8765563964844, 'neutral'), (349.185791015625, 'negative')]
#
# Superior quality, amazing fit, true to size. Recommend
# positive
# [(260.9216003417969, 'positive'), (347.15966796875, 'neutral'), (379.62420654296875, 'negative')]
#
# Love these joggers, not like the huge, no shape hoodie
# neutral
# [(1363.1514892578125, 'positive'), (1538.06396484375, 'neutral'), (1538.600830078125, 'negative')]
#
# Got both top and bottom nice jogger oversized and the colours so nice
# positive
# [(1296.8494873046875, 'positive'), (1622.8135986328125, 'neutral'), (1826.679931640625, 'negative')]
#
# Good quality and very stylish. Feel really posh when I wear it!
# positive
# [(207.14071655273438, 'positive'), (261.912353515625, 'neutral'), (288.3648376464844, 'negative')]
#
# I felt really comfy  in this dress I got a lot of compliments love how it opens at the back I wore a size 10\r\nI‚Äôm usually a 12
# positive
# [(249.78196716308594, 'positive'), (281.4693908691406, 'neutral'), (298.8166198730469, 'negative')]
#
# This is really pretty for an out there type of dress, really good quality and love the back, it is quite big/oversized though
# positive
# [(379.834228515625, 'positive'), (416.17266845703125, 'neutral'), (425.9889221191406, 'negative')]
#
# I ordered a size 8 and it looked like a size 14 on me, I sent it back and ordered a size 6 and there was no difference at all, the shirt is/was too big and I sent it back thou I really like the colour. I recommend it for people who like their clothes really big.
# neutral
# [(41.18903732299805, 'negative'), (42.29106903076172, 'neutral'), (42.853790283203125, 'positive')]
#
# I sent this blouse back to you because it was far too big for me it was a really lovely blouse
# positive
# [(217.19415283203125, 'positive'), (258.68548583984375, 'negative'), (261.6070251464844, 'neutral')]
#
# Lovely material more like posh pyjamas to me couldn‚Äôt wear them out
# positive
# [(2264.04296875, 'negative'), (2734.749267578125, 'neutral'), (2881.93701171875, 'positive')]
#
# Love the pattern and fit of this shirt - got the bottoms and bikini top to match and it looks great together
# positive
# [(238.23794555664062, 'positive'), (283.9689025878906, 'neutral'), (317.3951721191406, 'negative')]
#
# I bought this for my brother‚Äôs white coat ceremony. I looked very graceful
# positive
# [(1282.7716064453125, 'positive'), (1648.0579833984375, 'neutral'), (1716.5650634765625, 'negative')]
#
# I purchased size 6 and I was drowning in them!  Size is not reflected accurately.  I was disappointed as the fabric looked fun to wear.
# negative
# [(210.2185821533203, 'negative'), (241.18936157226562, 'neutral'), (244.56326293945312, 'positive')]
#
# Lovely material just felt like I had pyjamas on and they wasn‚Äôt white more like cream
# positive
# [(1353.4730224609375, 'positive'), (1379.69482421875, 'negative'), (1441.8614501953125, 'neutral')]
#
# I needed a new black skirt for the summer, this fit the bill! Great price and fit as expected
# positive
# [(271.03765869140625, 'positive'), (307.2039489746094, 'neutral'), (356.0893249511719, 'negative')]
#
# Not a great fit. No stretch, a bit baggie in the stomach. Material is nice though.
# negative
# [(135.85675048828125, 'negative'), (142.0980987548828, 'neutral'), (163.81849670410156, 'positive')]
#
# Really pleased with this skirt, flattering and true to size. The ring detail makes it a bit different too. I wore this loads on holiday üòä
# positive
# [(447.2411193847656, 'positive'), (508.81512451171875, 'neutral'), (547.1644897460938, 'negative')]
#
# i would definitely say this is for curvy girls. i don‚Äôt have much of a hip but it still makes me look good.
# positive
# [(219.68313598632812, 'positive'), (242.488525390625, 'neutral'), (268.11138916015625, 'negative')]
#
# Really flattering and pretty although zip is a bit stiff
# positive
# [(685.45166015625, 'positive'), (761.3518676757812, 'neutral'), (784.1331787109375, 'negative')]
#
# I love how soft and cozy this top is. Also fits great
# positive
# [(256.9170227050781, 'positive'), (313.96588134765625, 'neutral'), (361.3375244140625, 'negative')]
#
# I am so happy with this purchase. It fits well and I love the colour.
# positive
# [(143.06277465820312, 'positive'), (173.42356872558594, 'neutral'), (193.852294921875, 'negative')]
#
# It looks lovely and is really comfy but unfortunately it has started to bobble after only one wash!
# neutral
# [(259.64276123046875, 'negative'), (281.94866943359375, 'neutral'), (299.7251892089844, 'positive')]
#
# Beautiful nude colour top, it‚Äôs comfortable and looks great with jeans.
# positive
# [(534.83544921875, 'positive'), (627.6251831054688, 'neutral'), (712.5787963867188, 'negative')]
#
# Pretty but very thin. Also more on the yellow side.
# negative
# [(429.4530334472656, 'negative'), (450.46826171875, 'neutral'), (477.72235107421875, 'positive')]
#
# The fabric is incredibly thin and completely sheer and see through. It is cheap quality, and looks it.
# negative
# [(259.3597412109375, 'negative'), (297.48065185546875, 'neutral'), (325.4455871582031, 'positive')]
#
# Beautiful skirt but not lined at all so totally see through even with nude coloured underwear you can see everything
# negative
# [(679.3346557617188, 'negative'), (787.316650390625, 'neutral'), (833.2233276367188, 'positive')]
#
# Very pretty but it is so thin. I ended up returning it unfortunately. It would be very cool in the summer but it is not wearable often
# negative
# [(201.6323699951172, 'negative'), (221.38986206054688, 'neutral'), (236.77462768554688, 'positive')]
#
# Bought the top and skirt absolutely  beautiful.  However I  did  end up buying  2 of the  skirts as they are  really  see through.  I wear both  skirts  at the same  time   as they are a  wrap skirt.  Honestly  you can't  tell  I'm wearing  2 it just  makes it  less see through.
# neutral
# [(91.15543365478516, 'negative'), (92.31829071044922, 'positive'), (92.34153747558594, 'neutral')]
#
# Could‚Äôve been lovely, but it was such a crayon yellow colour, not creamy or light yellow and it was completely see through.
# negative
# [(451.5799560546875, 'negative'), (488.80499267578125, 'neutral'), (527.1182861328125, 'positive')]
#
# Very stylish. It fits well, you can dress this shirt up and dress it down too
# positive
# [(274.6751403808594, 'positive'), (333.6884460449219, 'neutral'), (369.7466125488281, 'negative')]
#
# I really wanted to love this blouse as bought the matching shorts. But the sleeves were ridiculously long. Or perhaps I have teeny tiny arms! I‚Äôm 5‚Äô3‚Äù so that may be. \r\nLike the material, but really big made. I‚Äôm usually an 8-10, big busted but even the 8 was huge all over.
# neutral
# [(135.5779571533203, 'negative'), (139.7967071533203, 'neutral'), (141.488037109375, 'positive')]
#
# Great top, but it was not for me. It was too big, I think. However, the quality of the garment is on point! Sorry, it did not look great on me.
# neutral
# [(97.25949096679688, 'negative'), (98.46331024169922, 'neutral'), (105.31146240234375, 'positive')]
#
# The button fell off as I was trying it on and had to return it
# neutral
# [(250.79904174804688, 'negative'), (308.2826843261719, 'neutral'), (318.6576232910156, 'positive')]
#
# The material is nice and soft and the arms at a nice flare to the outfit. It fits well.
# positive
# [(272.3102722167969, 'positive'), (309.9739685058594, 'neutral'), (354.3001403808594, 'negative')]
#
# I‚Äôm a 5‚Äô 7‚Äù M-L and got the size 10, fit is good will be versatile for many outfits evening or day.
# negative
# [(267.1285400390625, 'positive'), (295.3601989746094, 'neutral'), (325.7725830078125, 'negative')]
#
# Compared to the top, the shorts run smaller but still great material
# neutral
# [(578.15625, 'positive'), (671.5572509765625, 'neutral'), (744.9723510742188, 'negative')]
#
# The fabric is cheap and the shorts are see-through. Couldn‚Äôt return bc it was a final sale.
# negative
# [(307.97265625, 'negative'), (336.2721252441406, 'neutral'), (382.7731628417969, 'positive')]
#
# Nice feel and quality, however we‚Äôre very much see through. Good fit.
# positive
# [(1004.2208862304688, 'neutral'), (1048.314453125, 'positive'), (1050.114990234375, 'negative')]
#
# Bit see through - would fine for holiday vibes though. They just didn't fit my body type unfortunately so sent back - think you could get nicer for cheaper too.  Tighter on waste for a size 10.
# neutral
# [(358.2879943847656, 'negative'), (370.0007629394531, 'neutral'), (392.5634460449219, 'positive')]
#
# Bought this for a disco themed party and I like it. The 6 is a little big, but it‚Äôs fine. The sequins are really scratchy on my skin, and the lining is really sheer so you need nipple covers or a bra. I‚Äôm going to change it out for something a little thicker. There‚Äôs also a lot of loose plastic strings that stick out on the dress. I‚Äôm going to cut them off, but I‚Äôm scared the sequins might start to fall. I hope it holds up but overall I‚Äôm not mad at the sale price.
# neutral
# [(52.022342681884766, 'negative'), (52.18864440917969, 'neutral'), (52.706729888916016, 'positive')]
#
# So unflattering. Weird fit. Just doesn't add anything. Just kinda baggy and strange looking
# negative
# [(291.8246765136719, 'negative'), (324.6732482910156, 'neutral'), (361.0177001953125, 'positive')]
#
# I wore this dress for my friend wedding few days ago. During the wedding the dress was always coming ‚¨ÜÔ∏è, and this made me feel really uncomfortable. Before buying it, I saw a bad review saying the dress is too short. But I fought that if I order a one size bigger it will fit better. But it didn‚Äôt work for me.
# negative
# [(150.90682983398438, 'negative'), (158.58963012695312, 'neutral'), (160.056396484375, 'positive')]
#
# I purchased a 14 and a 16. You would think these would have m9re material but you could see my cheeks
# negative
# [(385.6954650878906, 'negative'), (432.8117980957031, 'positive'), (439.8121032714844, 'neutral')]
#
# Way too short, fits like a blazer. Returned it right away
# negative
# [(399.27496337890625, 'negative'), (497.3734130859375, 'neutral'), (521.5344848632812, 'positive')]
#
# Love love love. Fit is perfect and very flattering. Having the top stitched together as it does have a tendency to fall open
# positive
# [(354.0162353515625, 'positive'), (421.63092041015625, 'neutral'), (434.7714538574219, 'negative')]
#
# I bought this a few weeks ago and love it.  It's a perfect size 8, not too heavy either.  I personally wasn't keen on the shoulder pads and took them out and it looks great without them.  Looks more expensive than it was.
# positive
# [(66.21444702148438, 'positive'), (69.73792266845703, 'neutral'), (74.23492431640625, 'negative')]
#
# I was positively surprised by the quality considering the very good price. However, I didn‚Äôt keep it because of the fitting. Leg was wider than the picture even the size was correct. If you are taller, it probably will be better.
# positive
# [(201.3287811279297, 'positive'), (202.12474060058594, 'negative'), (203.69993591308594, 'neutral')]
#
# Got great- high quality sister and the lining takes it up a level. Colour is unique. I get comments literally every time I wear them
# positive
# [(435.3398742675781, 'positive'), (535.861083984375, 'neutral'), (554.9498291015625, 'negative')]
#
# Love these, they fit so well and are so comfy. Really nice colour too. They are a bit more expensive than other faux leather trousers I have but they are thicker material
# positive
# [(143.0399932861328, 'positive'), (159.46067810058594, 'neutral'), (171.38978576660156, 'negative')]
#
# Loved this for a beach vacation. Fits very well. I‚Äôm 5‚Äô6 140lbs and bought a size 8.
# positive
# [(291.4554443359375, 'positive'), (327.3287658691406, 'neutral'), (357.7535095214844, 'negative')]
#
# Wore this on vacation. Received compliments on the dress all day long. The fit was perfect. I was afraid I‚Äôd have to keep adjusting this dress since it‚Äôs strapless but I had no issues at all. Super cute and so comfortable!
# positive
# [(81.17133331298828, 'positive'), (90.02876281738281, 'neutral'), (93.1237564086914, 'negative')]
#
# The material is really thin and feels cheap. Recommend sizing up.
# negative
# [(211.9937744140625, 'negative'), (236.65611267089844, 'neutral'), (261.3986511230469, 'positive')]
#
# Perfect for the beach and really flattering! Got a lot of compliments when wearing it! I would size up 1 size though.
# positive
# [(126.91835021972656, 'positive'), (147.06942749023438, 'neutral'), (159.0801239013672, 'negative')]
#
# The material was very thin and was see-through, the sizing is also off. Dress comes up small and it‚Äôs deffo not for the big boobed babes
# negative
# [(372.6584777832031, 'negative'), (417.16925048828125, 'neutral'), (429.0070495605469, 'positive')]
#
# This will be perfect for when I go on holiday. It also fits nicely around my chest even though I have quite small boobs.
# positive
# [(195.22909545898438, 'positive'), (224.36715698242188, 'neutral'), (229.2564239501953, 'negative')]
#
# Waste of money having to pay for duties and then having to pay to return this, purchases like these make me never want to shop at Asos again.
# negative
# [(247.92904663085938, 'negative'), (269.0452575683594, 'neutral'), (283.4504699707031, 'positive')]
#
# I‚Äôm so glad I bought this dress. Usually I don‚Äôt wear items that expose my stomach area but this is lush. One of those dresses that gets you excited about summer!
# positive
# [(301.2921142578125, 'positive'), (337.19683837890625, 'neutral'), (356.0506591796875, 'negative')]
#
# Are usually wear a 10/12 in dresses I am an E cup wouldn‚Äôt zip up by my chest bottom half was fine. Not the best for larger chested women
# neutral
# [(562.6373901367188, 'negative'), (591.2109985351562, 'neutral'), (625.3148193359375, 'positive')]
#
# At ¬£42 I‚Äôd expect the dress to at least be lined but it is extremely thin and almost see through. Will be returning.
# negative
# [(207.0623016357422, 'negative'), (222.7044677734375, 'neutral'), (238.64486694335938, 'positive')]

# %%
from sklearn.metrics import classification_report

def classify_dataset(reviews, prompt_function, answers):
    all_predictions = [most_probable_answer(*prompt_function(review), answers=answers) for review, _ in tqdm(reviews)]
    all_predictions = [min(answers)[1] for answers in all_predictions]
    all_labels = [sentiment for _, sentiment in reviews]

    print(classification_report(all_labels, all_predictions))

# %%
not_neutral_sentiments = [sentiment for sentiment in sentiments if sentiment != "neutral"]

not_neutral_dataframe = asos_dataframe[asos_dataframe[sentiment_column] != "neutral"]
not_neutral_review_sentiments = not_neutral_dataframe[[review_column, sentiment_column]].to_numpy()

question = "What is the sentiment of the following review of a clothing item?"
print("Version 1, filtered out neutral")
classify_dataset(not_neutral_review_sentiments, lambda review: (question, "REVIEW:", review, "The sentiment is "), not_neutral_sentiments)
# Out:
# Version 1, filtered out neutral
# 100%|██████████| 173/173 [01:19<00:00,  2.16it/s]
#               precision    recall  f1-score   support
#
#     negative       0.80      0.97      0.87        61
#     positive       0.98      0.87      0.92       112
#
#     accuracy                           0.90       173
#    macro avg       0.89      0.92      0.90       173
# weighted avg       0.92      0.90      0.90       173

# %%
question = "What is the sentiment of the following review of a clothing item?"
print("Version 1, including neutral")
classify_dataset(review_sentiments, lambda review: (question, "REVIEW:", review, "The sentiment is "), sentiments)
# Out:
# Version 1, including neutral
# 100%|██████████| 199/199 [02:15<00:00,  1.47it/s]
#               precision    recall  f1-score   support
#
#     negative       0.62      0.95      0.75        61
#      neutral       0.43      0.12      0.18        26
#     positive       0.96      0.85      0.90       112
#
#     accuracy                           0.78       199
#    macro avg       0.67      0.64      0.61       199
# weighted avg       0.79      0.78      0.76       199

# %%
def few_shot(reviews, number):
    chosen_reviews = random.sample(list(reviews), number)

    given = "Given the following review:"
    extract = "Your task is to extract the following sentiment:"
    return "\n".join("\n".join((given, review, extract, sentiment)) for review, sentiment in chosen_reviews)

# %%
number = 1
question = "What is the sentiment of the following review of a clothing item?"
prompt_function = lambda review: (few_shot(review_sentiments, number), question, "REVIEW:", review, "The sentiment is ")

classify_dataset(review_sentiments, prompt_function, sentiments)
# Out:
# 100%|██████████| 199/199 [02:18<00:00,  1.43it/s]
#               precision    recall  f1-score   support
#
#     negative       0.64      0.67      0.66        61
#      neutral       0.19      0.19      0.19        26
#     positive       0.80      0.78      0.79       112
#
#     accuracy                           0.67       199
#    macro avg       0.54      0.55      0.55       199
# weighted avg       0.67      0.67      0.67       199

# %%
number = 2
question = "What is the sentiment of the following review of a clothing item?"
prompt_function = lambda review: (few_shot(review_sentiments, number), question, "REVIEW:", review, "The sentiment is ")

classify_dataset(review_sentiments, prompt_function, sentiments)
# Out:
# 100%|██████████| 199/199 [04:00<00:00,  1.21s/it]
#               precision    recall  f1-score   support
#
#     negative       0.64      0.72      0.68        61
#      neutral       0.08      0.08      0.08        26
#     positive       0.92      0.86      0.89       112
#
#     accuracy                           0.71       199
#    macro avg       0.55      0.55      0.55       199
# weighted avg       0.73      0.71      0.72       199

# %%
number = 5
question = "What is the sentiment of the following review of a clothing item?"
prompt_function = lambda review: (few_shot(review_sentiments, number), question, "REVIEW:", review, "The sentiment is ")

classify_dataset(review_sentiments, prompt_function, sentiments)
# Out:
# 100%|██████████| 199/199 [12:18<00:00,  3.71s/it]
#               precision    recall  f1-score   support
#
#     negative       0.69      0.80      0.74        61
#      neutral       0.27      0.31      0.29        26
#     positive       0.94      0.82      0.88       112
#
#     accuracy                           0.75       199
#    macro avg       0.63      0.64      0.63       199
# weighted avg       0.77      0.75      0.76       199
